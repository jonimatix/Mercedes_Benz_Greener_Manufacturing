# %%
import pandas as pd
import xgboost as xgb
import numpy as np
from scipy.stats import uniform as sp_rand
from scipy.stats import randint as sp_randint
from sklearn.metrics import r2_score, make_scorer
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## 7. Experiment

# %%
# data
dt_model = pd.read_csv("../../data/Mercedes_Benz_Greener_Manufacturing/data/dt_all_preprocess.csv")
params_xgb = pickle.load(open("../../data/Mercedes_Benz_Greener_Manufacturing/data/params_xgb_05.pkl", "rb"))

# %%
params_xgb
# Out:
# {'booster': 'dart',
#  'colsample_bylevel': 0.65042324081507141,
#  'colsample_bytree': 0.56331500103746779,
#  'gamma': 2.3341376475299098,
#  'learning_rate': 0.0085150298365250371,
#  'max_depth': 2,
#  'min_child_weight': 13,
#  'n_estimators': 899,
#  'reg_alpha': 0.37056910563097056,
#  'reg_lambda': 0.19002316325694815,
#  'subsample': 0.8017841107570316}

# %%
# r_2 for xgboost
def r_2(preds, dtrain):
    labels = dtrain.get_label()
    return 'score', r2_score(labels, preds)

# make scorer_r2
scorer_r2 = make_scorer(r2_score)

# %% [markdown]
# ### 7.1 Add ID as a feature (improved)

# %%
# X, y, ID
X_train_all = dt_model.loc[dt_model["IsTrainTest"] == "train"].drop(["y", "IsTrainTest"], axis = 1)
X_test = dt_model.loc[dt_model["IsTrainTest"] == "test"].drop(["y", "IsTrainTest"], axis = 1)
y_train_all = dt_model.loc[dt_model["IsTrainTest"] == "train"].y.values
y_test = dt_model.loc[dt_model["IsTrainTest"] == "test"].y.values
ID_train_all = dt_model.loc[dt_model["IsTrainTest"] == "train"].ID.values
ID_test = dt_model.loc[dt_model["IsTrainTest"] == "test"].ID.values

# %%
# xgbDmatrix
dmx_train_all = xgb.DMatrix(X_train_all, label = y_train_all)
dmx_test = xgb.DMatrix(X_test)

# %%
# cv
cv_xgb = xgb.cv(params_xgb, dmx_train_all
                , num_boost_round = 1000
                , nfold = 10
                , feval = r_2, maximize = True, early_stopping_rounds = 50
                , show_stdv = True, verbose_eval = 50)

# %%
cv_xgb.tail()

# %%
# train
model_xgb = xgb.train(params_xgb, dmx_train_all, num_boost_round = cv_xgb.shape[0])

# %%
# importance
fig, ax = plt.subplots(figsize = (12,18))
xgb.plot_importance(model_xgb, max_num_features = 50, height = 0.8, ax = ax)
plt.show()

# %%
# predict
y_test = model_xgb.predict(dmx_test)
y_test[:10]

# %%
# submit
dt_submit = pd.DataFrame({"ID": ID_test, "y": y_test})

# %%
dt_submit.to_csv("../../data/Mercedes_Benz_Greener_Manufacturing/submission/6_featEng_randomSearch_singleXgb_withID.csv", index = False)

# %% [markdown]
# ### 7.2 Not use OHE but Label

# %%
cols_ohe = dt_model.filter(regex = "Encode_ohe_").columns.values
dt_model = dt_model.drop(cols_ohe, axis = 1)

# %%
# X, y, ID
X_train_all = dt_model.loc[dt_model["IsTrainTest"] == "train"].drop(["y", "IsTrainTest"], axis = 1)
X_test = dt_model.loc[dt_model["IsTrainTest"] == "test"].drop(["y", "IsTrainTest"], axis = 1)
y_train_all = dt_model.loc[dt_model["IsTrainTest"] == "train"].y.values
y_test = dt_model.loc[dt_model["IsTrainTest"] == "test"].y.values
ID_train_all = dt_model.loc[dt_model["IsTrainTest"] == "train"].ID.values
ID_test = dt_model.loc[dt_model["IsTrainTest"] == "test"].ID.values

# %%
# xgbDmatrix
dmx_train_all = xgb.DMatrix(X_train_all, label = y_train_all)
dmx_test = xgb.DMatrix(X_test)

# %%
# cv
cv_xgb = xgb.cv(params_xgb, dmx_train_all
                , num_boost_round = 1000
                , nfold = 10
                , feval = r_2, maximize = True, early_stopping_rounds = 50
                , show_stdv = True, verbose_eval = 50)
# Out:
# [0]	train-rmse:100.1+0.0803089	train-score:-61.4135+0.918969	test-rmse:100.098+0.727737	test-score:-62.5119+7.01993
# [50]	train-rmse:65.6133+0.0587116	train-score:-25.8157+0.385122	test-rmse:65.6112+0.665871	test-score:-26.272+2.90946
# [100]	train-rmse:43.278+0.0529504	train-score:-10.6663+0.15805	test-rmse:43.277+0.702295	test-score:-10.8534+1.18735
# [150]	train-rmse:28.9434+0.0608377	train-score:-4.21782+0.0615286	test-rmse:28.9396+0.79993	test-score:-4.29155+0.477328
# [200]	train-rmse:19.9192+0.076482	train-score:-1.47125+0.0221463	test-rmse:19.9155+0.94147	test-score:-1.49984+0.2006
# [250]	train-rmse:14.4473+0.101817	train-score:-0.29994+0.00806089	test-rmse:14.4461+1.09675	test-score:-0.311895+0.116048
# [300]	train-rmse:11.3225+0.127392	train-score:0.201617+0.00859451	test-rmse:11.3269+1.22783	test-score:0.194741+0.100065
# [350]	train-rmse:9.66642+0.148109	train-score:0.418084+0.0105216	test-rmse:9.68756+1.30649	test-score:0.411089+0.0969821
# ...

# %%
cv_xgb.tail()
# Out:
#      test-rmse-mean  test-rmse-std  test-score-mean  test-score-std  \
# 790        8.233332       1.310784         0.574621        0.087098
# 791        8.232921       1.310815         0.574663        0.087103
# 792        8.232964       1.310945         0.574659        0.087109
# 793        8.232891       1.310897         0.574666        0.087109
# 794        8.232780       1.310894         0.574679        0.087104
#
#      train-rmse-mean  train-rmse-std  train-score-mean  train-score-std
# 790         7.964664        0.166125          0.604919         0.011336
# 791         7.964078        0.166043          0.604977         0.011329
# 792         7.963390        0.166038          0.605045         0.011328
# 793         7.962871        0.165966          0.605097         0.011318
# 794         7.962257        0.165870          0.605158         0.011305

# %%
# train
model_xgb = xgb.train(params_xgb, dmx_train_all, num_boost_round = cv_xgb.shape[0])

# %%
# importance
fig, ax = plt.subplots(figsize = (12,18))
xgb.plot_importance(model_xgb, max_num_features = 50, height = 0.8, ax = ax)
plt.show()

# %%
# predict
y_test = model_xgb.predict(dmx_test)
y_test[:10]
# Out:
# array([  78.63989258,   93.23760986,   79.07484436,   78.48136139,
#         111.36470032,   92.44545746,  111.33235931,   93.40052795,
#         115.09927368,   93.96344757], dtype=float32)

# %%
# submit
dt_submit = pd.DataFrame({"ID": ID_test, "y": y_test})

# %%
dt_submit.to_csv("../../data/Mercedes_Benz_Greener_Manufacturing/submission/7_featEng_randomSearch_singleXgb_withID_noOHE_withLabelEncode_withOrdinalX5.csv", index = False)
